# %%
from bs4 import BeautifulSoup
import requests
import os
import re
import numpy as np
import pandas as pd

# %%
#list the years we want to scrape
years = ['2018', '2014', '2010', '2006', '2002', '1998', '1994']
years = ['2018']

# %%
for y in years:
    url = f'https://en.wikipedia.org/wiki/{y}_FIFA_World_Cup_squads'
    html = requests.get(url)
    print(html)
    soup = BeautifulSoup(html.text, 'html.parser')
    result = soup.find_all('table')
    
    for i in np.arange(0, len(result)+1):
        result[i]
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
#       6 result = soup.find_all('table')
#       8 for i in np.arange(0, len(result)+1):
# ----> 9     result[i]
#
# IndexError: list index out of range

# %%
t = BeautifulSoup(html.text, 'html.parser')    
result = t.find_all('table')
#print(result[0])
#np.arange(0, len(result)+1)
table = pd.read_html(str(result))
table[0]
# Out:
#     No. Pos.                     Player  Date of birth (age)  Caps  Goals  \
# 0     1   GK  Essam El Hadary (captain)                  NaN   158      0
# 1     2   DF                   Ali Gabr                  NaN    21      1
# 2     3   DF           Ahmed Elmohamady                  NaN    78      2
# 3     4   MF                 Omar Gaber                  NaN    24      0
# 4     5   MF                  Sam Morsy                  NaN     5      0
# 5     6   DF               Ahmed Hegazi                  NaN    45      1
# 6     7   DF                Ahmed Fathy                  NaN   126      3
# 7     8   MF                Tarek Hamed                  NaN    21      0
# 8     9   FW              Marwan Mohsen                  NaN    24      4
# 9    10   FW              Mohamed Salah                  NaN    57     33
# 10   11   FW                    Kahraba                  NaN    19      3
# 11   12   DF               Ayman Ashraf                  NaN     4      0
# 12   13   DF        Mohamed Abdel Shafy                  NaN    51      1
# 13   14   FW              Ramadan Sobhi                  NaN    23      1
# 14   15   DF              Mahmoud Hamdy                  NaN     0      0
# 15   16   GK              Sherif Ekramy                  NaN    22      0
# 16   17   MF             Mohamed Elneny                  NaN    61      5
# 17   18   FW                  Shikabala                  NaN    29      2
# 18   19   MF           Abdallah El Said                  NaN    36      6
# 19   20   DF                 Saad Samir                  NaN    11      0
# 20   21   MF                  Trézéguet                  NaN    24      2
# 21   22   FW                  Amr Warda                  NaN    16      0
# 22   23   GK         Mohamed El Shenawy                  NaN     3      0
#
#                     Club
# 0             Al Taawoun
# 1   West Bromwich Albion
# 2            Aston Villa
# 3         Los Angeles FC
# 4         Wigan Athletic
# 5   West Bromwich Albion
# 6                Al Ahly
# 7                Zamalek
# 8                Al Ahly
# 9              Liverpool
# 10            Al-Ittihad
# 11               Al Ahly
# 12              Al Fateh
# 13            Stoke City
# 14               Zamalek
# 15               Al Ahly
# 16               Arsenal
# 17               Al Raed
# 18                  KuPS
# 19               Al Ahly
# 20             Kasımpaşa
# 21             Atromitos
# 22               Al Ahly
