# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Tournament/Country Analysis

# %%
all_data = pd.read_csv('raw_data/international_matches.csv')
all_data.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %%
all_data = all_data.drop(columns=['home_team_goalkeeper_score', 'away_team_goalkeeper_score', 'home_team_mean_defense_score', 'away_team_mean_defense_score', 'home_team_mean_offense_score', 'away_team_mean_offense_score', 'home_team_mean_midfield_score', 'away_team_mean_midfield_score'])
all_data.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %%
all_data['better_team_win'] = (all_data.)

# %% [markdown]
# ### EA Team Rating Analysis

# %%
ea_fifa_data = all_data.dropna()
ea_fifa_data['home_team_mean_total_score'] = round(((ea_fifa_data.home_team_goalkeeper_score + ea_fifa_data.home_team_mean_defense_score + ea_fifa_data.home_team_mean_midfield_score + ea_fifa_data.home_team_mean_offense_score)/4), 1)
ea_fifa_data['away_team_mean_total_score'] = round(((ea_fifa_data.away_team_goalkeeper_score + ea_fifa_data.away_team_mean_defense_score + ea_fifa_data.away_team_mean_midfield_score + ea_fifa_data.away_team_mean_offense_score)/4), 1)
# Out:
# C:\Users\dejans.THOMASPUMP\AppData\Local\Temp\ipykernel_5512\4194663519.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ea_fifa_data['home_team_mean_total_score'] = round(((ea_fifa_data.home_team_goalkeeper_score + ea_fifa_data.home_team_mean_defense_score + ea_fifa_data.home_team_mean_midfield_score + ea_fifa_data.home_team_mean_offense_score)/4), 1)
# C:\Users\dejans.THOMASPUMP\AppData\Local\Temp\ipykernel_5512\4194663519.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
ea_fifa_data
# Out:
#              date               home_team            away_team  \
# 8264   2004-09-03                   Spain             Scotland
# 8266   2004-09-04                 Austria              England
# 8271   2004-09-04                 Croatia              Hungary
# 8276   2004-09-04                 Iceland             Bulgaria
# 8278   2004-09-04                   Italy               Norway
# ...           ...                     ...                  ...
# 23909  2022-06-14                  Poland              Belgium
# 23911  2022-06-14                 Ukraine  Republic of Ireland
# 23912  2022-06-14  Bosnia and Herzegovina              Finland
# 23913  2022-06-14                 Romania           Montenegro
# 23918  2022-06-14                   Chile                Ghana
#
#       home_team_continent away_team_continent  home_team_fifa_rank  \
# 8264               Europe              Europe                    3
# 8266               Europe              Europe                   90
# ...

# %%
len(all_data.home_team.unique())
# Out:
# 211
